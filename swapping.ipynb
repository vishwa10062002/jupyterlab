# %%
a=int(input("enter value of a:"))
b=int(input("enter value of b:"))
t=a
a=b
b=t
print("after swapping")
print("value of a:",a)
print("value of b:",b)
# Out:
# enter value of a: 4
# enter value of b: 8
# after swapping
# value of a: 8
# value of b: 4
