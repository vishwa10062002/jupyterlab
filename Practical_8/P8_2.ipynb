# %%
import matplotlib.pyplot as plt
plt.plot([5,15], label="rice", marker="o", color="red")
plt.plot([3,6], label="oil", marker="o", color="blue")
plt.plot([8.0010, 14.2], label="wheat", marker="o", color="green")
plt.plot([1.95412, 6.98547, 5.41411, 5.99, 7.9999], label="coffee", marker="o", color="purple")
plt.legend()
plt.show()
